# %% [markdown]
# ## Forecasting the Airlines Passengers data set

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
import seaborn as sns

# %% [markdown]
# ### IMPORTING DATA

# %%
airlines=pd.read_excel('C:\\Users\\wARcRACK\\ExcelRAssignments\\Assignment18(Forecasting)\\Datasets\\Airlines+Data.xlsx')

# %%
airlines
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306
#
# [96 rows x 2 columns]

# %%
airlines.head(10)
# Out:
#        Month  Passengers
# 0 1995-01-01         112
# 1 1995-02-01         118
# 2 1995-03-01         132
# 3 1995-04-01         129
# 4 1995-05-01         121
# 5 1995-06-01         135
# 6 1995-07-01         148
# 7 1995-08-01         148
# 8 1995-09-01         136
# 9 1995-10-01         119

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       96 non-null     datetime64[ns]
#  1   Passengers  96 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.6 KB

# %%
airlines.describe()
# Out:
#                      Month  Passengers
# count                   96   96.000000
# mean   1998-12-16 05:00:00  213.708333
# min    1995-01-01 00:00:00  104.000000
# 25%    1996-12-24 06:00:00  156.000000
# 50%    1998-12-16 12:00:00  200.000000
# 75%    2000-12-08 18:00:00  264.750000
# max    2002-12-01 00:00:00  413.000000
# std                    NaN   71.918216

# %% [markdown]
# ## Line plot

# %%
# create a line plot
from pandas import read_csv
from matplotlib import pyplot

# %%
airlines1 =pd. read_excel("C:\\Users\\wARcRACK\\ExcelRAssignments\\Assignment18(Forecasting)\\Datasets\\Airlines+Data.xlsx", header=0, index_col=0,parse_dates=True)
airlines1.plot()
pyplot.show()

# %%
airlines1
# Out:
#             Passengers
# Month
# 1995-01-01         112
# 1995-02-01         118
# 1995-03-01         132
# 1995-04-01         129
# 1995-05-01         121
# ...                ...
# 2002-08-01         405
# 2002-09-01         355
# 2002-10-01         306
# 2002-11-01         271
# 2002-12-01         306
#
# [96 rows x 1 columns]

# %% [markdown]
# ## Histogram and Density Plots

# %%
# create a histogram plot
airlines1.hist()
pyplot.show()

# %%
airlines1.Passengers.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Lag plot

# %%
# create a scatter plot

from pandas.plotting import lag_plot

lag_plot(airlines1)
pyplot.show()

# %% [markdown]
# # ACF PLot

# %%
# create an autocorrelation plot

from statsmodels.graphics.tsaplots import plot_acf
plot_acf(airlines1,lags=30)
pyplot.show()

# %% [markdown]
# ## SquareTransformation

# %%
from pandas import read_csv
from pandas import DataFrame
from numpy import sqrt
from matplotlib import pyplot

# %% [markdown]
# # Upsampling the data to each and every day

# %%
upsampled = airlines1.resample('D').mean()
print(upsampled.head(32))
# Out:
#             Passengers
# Month
# 1995-01-01       112.0
# 1995-01-02         NaN
# 1995-01-03         NaN
# 1995-01-04         NaN
# 1995-01-05         NaN
# 1995-01-06         NaN
# 1995-01-07         NaN
# 1995-01-08         NaN
# 1995-01-09         NaN
# 1995-01-10         NaN
# 1995-01-11         NaN
# 1995-01-12         NaN
# 1995-01-13         NaN
# 1995-01-14         NaN
# 1995-01-15         NaN
# 1995-01-16         NaN
# 1995-01-17         NaN
# 1995-01-18         NaN
# 1995-01-19         NaN
# 1995-01-20         NaN
# 1995-01-21         NaN
# 1995-01-22         NaN
# 1995-01-23         NaN
# 1995-01-24         NaN
# 1995-01-25         NaN
# 1995-01-26         NaN
# 1995-01-27         NaN
# 1995-01-28         NaN
# 1995-01-29         NaN
# 1995-01-30         NaN
# 1995-01-31         NaN
# 1995-02-01       118.0

# %%
##### interpolate the missing value
interpolated = upsampled.interpolate(method='linear')
print(interpolated.head(32))
interpolated.plot()
pyplot.show()
# Out:
#             Passengers
# Month
# 1995-01-01  112.000000
# 1995-01-02  112.193548
# 1995-01-03  112.387097
# 1995-01-04  112.580645
# 1995-01-05  112.774194
# 1995-01-06  112.967742
# 1995-01-07  113.161290
# 1995-01-08  113.354839
# 1995-01-09  113.548387
# 1995-01-10  113.741935
# 1995-01-11  113.935484
# 1995-01-12  114.129032
# 1995-01-13  114.322581
# 1995-01-14  114.516129
# 1995-01-15  114.709677
# 1995-01-16  114.903226
# 1995-01-17  115.096774
# 1995-01-18  115.290323
# 1995-01-19  115.483871
# 1995-01-20  115.677419
# 1995-01-21  115.870968
# 1995-01-22  116.064516
# 1995-01-23  116.258065
# 1995-01-24  116.451613
# 1995-01-25  116.645161
# 1995-01-26  116.838710
# 1995-01-27  117.032258
# 1995-01-28  117.225806
# 1995-01-29  117.419355
# 1995-01-30  117.612903
# 1995-01-31  117.806452
# 1995-02-01  118.000000

# %% [markdown]
# # Before Transformation

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(interpolated)
# histogram
pyplot.subplot(212)
pyplot.hist(interpolated)
pyplot.show()

# %%
interpolated
# Out:
#             Passengers
# Month
# 1995-01-01  112.000000
# 1995-01-02  112.193548
# 1995-01-03  112.387097
# 1995-01-04  112.580645
# 1995-01-05  112.774194
# ...                ...
# 2002-11-27  301.333333
# 2002-11-28  302.500000
# 2002-11-29  303.666667
# 2002-11-30  304.833333
# 2002-12-01  306.000000
#
# [2892 rows x 1 columns]

# %% [markdown]
# # Square Root Transform

# %%
dataframe = DataFrame(interpolated)
dataframe.columns = ['Passengers']
dataframe['Passengers'] = sqrt(dataframe['Passengers'])

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(dataframe['Passengers'])
# histogram
pyplot.subplot(212)
pyplot.hist(dataframe['Passengers'])
pyplot.show()

# %%
interpolated
# Out:
#             Passengers
# Month
# 1995-01-01  112.000000
# 1995-01-02  112.193548
# 1995-01-03  112.387097
# 1995-01-04  112.580645
# 1995-01-05  112.774194
# ...                ...
# 2002-11-27  301.333333
# 2002-11-28  302.500000
# 2002-11-29  303.666667
# 2002-11-30  304.833333
# 2002-12-01  306.000000
#
# [2892 rows x 1 columns]

# %% [markdown]
# # Log Transform

# %%
from numpy import log
dataframe = DataFrame(interpolated)
dataframe.columns = ['Passengers']
dataframe['Passengers'] = log(dataframe['Passengers'])

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(dataframe['Passengers'])
# histogram
pyplot.subplot(212)
pyplot.hist(dataframe['Passengers'])
pyplot.show()

# %%
interpolated
# Out:
#             Passengers
# Month
# 1995-01-01  112.000000
# 1995-01-02  112.193548
# 1995-01-03  112.387097
# 1995-01-04  112.580645
# 1995-01-05  112.774194
# ...                ...
# 2002-11-27  301.333333
# 2002-11-28  302.500000
# 2002-11-29  303.666667
# 2002-11-30  304.833333
# 2002-12-01  306.000000
#
# [2892 rows x 1 columns]

# %%
interpolated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2892 entries, 1995-01-01 to 2002-12-01
# Freq: D
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Passengers  2892 non-null   float64
# dtypes: float64(1)
# memory usage: 45.2 KB

# %% [markdown]
# # Plotting Heatmap

# %%
airlines
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306
#
# [96 rows x 2 columns]

# %%
airlines["Date"]=pd.to_datetime(airlines.Month,format="%b-%y")
airlines["Months"]=airlines.Date.dt.strftime("%b")
airlines["Year"]=airlines.Date.dt.strftime("%Y")

# %%
# Heatmap
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
heatmap_y_month = pd.pivot_table(data=airlines,values="Passengers",index="Year",columns="Month",aggfunc="mean",fill_value=0)
sns.heatmap(heatmap_y_month,annot=True,fmt="g") #fmt is format of the grid values
# Out:
# <Axes: xlabel='Month', ylabel='Year'>

# %%
sns.boxplot(x="Months",y="Passengers",data=airlines)
# Out:
# <Axes: xlabel='Months', ylabel='Passengers'>

# %%
# Boxplot
plt.figure(figsize=(8,6))
plt.subplot(211)
sns.boxplot(x="Months",y="Passengers",data=airlines)
plt.subplot(212)
sns.boxplot(x="Year",y="Passengers",data=airlines)
# Out:
# <Axes: xlabel='Year', ylabel='Passengers'>

# %%
Month_Dummies = pd.DataFrame(pd.get_dummies(airlines['Months']))
airline1 = pd.concat([airlines,Month_Dummies],axis = 1)

# %%
airline1["t"] = np.arange(1,97)
airline1["t_squared"] = airline1["t"]*airline1["t"]
airline1["Log_Passengers"] = np.log(airline1["Passengers"])

# %%
airline1
# Out:
#         Month  Passengers       Date Months  Year    Apr    Aug    Dec    Feb  \
# 0  1995-01-01         112 1995-01-01    Jan  1995  False  False  False  False
# 1  1995-02-01         118 1995-02-01    Feb  1995  False  False  False   True
# 2  1995-03-01         132 1995-03-01    Mar  1995  False  False  False  False
# 3  1995-04-01         129 1995-04-01    Apr  1995   True  False  False  False
# 4  1995-05-01         121 1995-05-01    May  1995  False  False  False  False
# ..        ...         ...        ...    ...   ...    ...    ...    ...    ...
# 91 2002-08-01         405 2002-08-01    Aug  2002  False   True  False  False
# 92 2002-09-01         355 2002-09-01    Sep  2002  False  False  False  False
# 93 2002-10-01         306 2002-10-01    Oct  2002  False  False  False  False
# 94 2002-11-01         271 2002-11-01    Nov  2002  False  False  False  False
# 95 2002-12-01         306 2002-12-01    Dec  2002  False  False   True  False
#
#       Jan    Jul    Jun    Mar    May    Nov    Oct    Sep   t  t_squared  \
# 0    True  False  False  False  False  False  False  False   1          1
# 1   False  False  False  False  False  False  False  False   2          4
# 2   False  False  False   True  False  False  False  False   3          9
# 3   False  False  False  False  False  False  False  False   4         16
# 4   False  False  False  False   True  False  False  False   5         25
# ..    ...    ...    ...    ...    ...    ...    ...    ...  ..        ...
# 91  False  False  False  False  False  False  False  False  92       8464
# 92  False  False  False  False  False  False  False   True  93       8649
# 93  False  False  False  False  False  False   True  False  94       8836
# 94  False  False  False  False  False   True  False  False  95       9025
# 95  False  False  False  False  False  False  False  False  96       9216
#
#     Log_Passengers
# 0         4.718499
# 1         4.770685
# 2         4.882802
# 3         4.859812
# 4         4.795791
# ..             ...
# 91        6.003887
# 92        5.872118
# 93        5.723585
# 94        5.602119
# 95        5.723585
#
# [96 rows x 20 columns]

# %%
plt.figure(figsize=(12,3))
sns.lineplot(x="Year",y="Passengers",data=airlines)
# Out:
# C:\Users\wARcRACK\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\wARcRACK\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Passengers'>

# %% [markdown]
# # Moving Average

# %%
airlines.Passengers.plot(label="org")
for i in range(2,10,2):
    airlines["Passengers"].rolling(i).mean().plot(label=str(i))
plt.legend(loc=3)

# %%
airlines.Passengers.plot()
# Out:
# <Axes: >

# %%
import statsmodels.api as smf

seasonal_ts_add=smf.tsa.seasonal_decompose(airlines["Passengers"],freq=10)
seasonal_ts_add.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 import statsmodels.api as smf
# ----> 3 seasonal_ts_add=smf.tsa.seasonal_decompose(airlines["Passengers"],freq=10)
#       4 seasonal_ts_add.plot()
#
# TypeError: seasonal_decompose() got an unexpected keyword argument 'freq'

# %% [markdown]
# # Splitting data

# %%
Train = airline1.head(80)
Test = airline1.tail(16)

# %% [markdown]
# # Build Model & RMSE Value

# %%
# Linear Model
import statsmodels.formula.api as smf 
linear_model = smf.ols('Passengers~t',data=Train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(Test['t'])))
rmse_linear = np.sqrt(np.mean((np.array(Test['Passengers'])-np.array(pred_linear))**2))
rmse_linear

# %%
# Exponential Model
Exp = smf.ols('Log_Passengers~t',data=Train).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(Test['t'])))
rmse_Exp = np.sqrt(np.mean((np.array(Test['Passengers'])-np.array(np.exp(pred_Exp)))**2))
rmse_Exp

# %%
# Quadratic Model
Quad = smf.ols('Passengers~t+t_squared',data=Train).fit()
pred_Quad = pd.Series(Quad.predict(Test[["t","t_squared"]]))
rmse_Quad = np.sqrt(np.mean((np.array(Test['Passengers'])-np.array(pred_Quad))**2))
rmse_Quad

# %%
# Additive seasonality
add_sea = smf.ols('Passengers~Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov',data=Train).fit()
pred_add_sea = pd.Series(add_sea.predict(Test[['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov']]))
rmse_add_sea = np.sqrt(np.mean((np.array(Test['Passengers'])-np.array(pred_add_sea))**2))
rmse_add_sea

# %%
# Additive Seasonality quadrative

add_sea_Quad = smf.ols('Passengers~t+t_squared+Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov',data=Train).fit()
pred_add_sea_quad=pd.Series(add_sea_Quad.predict(Test[['t','t_squared','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov']]))
rmse_add_sea_quad = np.sqrt(np.mean((np.array(Test['Passengers'])-np.array(pred_add_sea_quad))**2))
rmse_add_sea_quad

# %%
#Multiplicative Seasonality

Mul_sea = smf.ols('Log_Passengers~Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov',data = Train).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(Test))
rmse_Mult_sea = np.sqrt(np.mean((np.array(Test['Passengers'])-np.array(np.exp(pred_Mult_sea)))**2))
rmse_Mult_sea
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 3
#       1 #Multiplicative Seasonality
# ----> 3 Mul_sea = smf.ols('Log_Passengers~Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov',data = Train).fit()
#       4 pred_Mult_sea = pd.Series(Mul_sea.predict(Test))
#       5 rmse_Mult_sea = np.sqrt(np.mean((np.array(Test['Passengers'])-np.array(np.exp(pred_Mult_sea)))**2))
#
# AttributeError: module 'statsmodels.api' has no attribute 'ols'

# %%
#Multiplicative addditive seasonality

Mul_Add_sea = smf.ols('Log_Passengers~t+Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov',data = Train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(Test))
rmse_Mult_add_sea = np.sqrt(np.mean((np.array(Test['Passengers'])-np.array(np.exp(pred_Mult_add_sea)))**2))
rmse_Mult_add_sea
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 3
#       1 #Multiplicative addditive seasonality
# ----> 3 Mul_Add_sea = smf.ols('Log_Passengers~t+Jan+Feb+Mar+Apr+May+Jun+Jul+Aug+Sep+Oct+Nov',data = Train).fit()
#       4 pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(Test))
#       5 rmse_Mult_add_sea = np.sqrt(np.mean((np.array(Test['Passengers'])-np.array(np.exp(pred_Mult_add_sea)))**2))
#
# AttributeError: module 'statsmodels.api' has no attribute 'ols'

# %% [markdown]
# # TESTING

# %%
data = {"MODEL":pd.Series(["rmse_linear","rmse_Exp","rmse_Quad","rmse_add_sea","rmse_add_sea_quad","rmse_Mult_sea","rmse_Mult_add_sea"]),"RMSE_Values":pd.Series([rmse_linear,rmse_Exp,rmse_Quad,rmse_add_sea,rmse_add_sea_quad,rmse_Mult_sea,rmse_Mult_add_sea])}
table_rmse=pd.DataFrame(data)
table_rmse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 data = {"MODEL":pd.Series(["rmse_linear","rmse_Exp","rmse_Quad","rmse_add_sea","rmse_add_sea_quad","rmse_Mult_sea","rmse_Mult_add_sea"]),"RMSE_Values":pd.Series([rmse_linear,rmse_Exp,rmse_Quad,rmse_add_sea,rmse_add_sea_quad,rmse_Mult_sea,rmse_Mult_add_sea])}
#       2 table_rmse=pd.DataFrame(data)
#       3 table_rmse
#
# NameError: name 'rmse_linear' is not defined

# %% [markdown]
# # PREDICT WITH NEW DATA

# %%
t = np.arange(97,108)
t
# Out:
# array([ 97,  98,  99, 100, 101, 102, 103, 104, 105, 106, 107])

# %%
t_squared=np.array(t*t)
t_squared
# Out:
# array([ 9409,  9604,  9801, 10000, 10201, 10404, 10609, 10816, 11025,
#        11236, 11449])

# %%
Month = pd.DataFrame({'Month':['2003-01-01','2003-02-01','2003-03-01','2003-04-01','2003-05-01','2003-06-01','2003-07-01',
                               '2003-08-01','2003-09-01','2003-10-01','2003-10-01']})

# %%
df={'t':t,'t_squared':t_squared}
df=pd.DataFrame(df)

# %%
newdata = pd.concat([Month,df],axis=1)
newdata
# Out:
#          Month    t  t_squared
# 0   2003-01-01   97       9409
# 1   2003-02-01   98       9604
# 2   2003-03-01   99       9801
# 3   2003-04-01  100      10000
# 4   2003-05-01  101      10201
# 5   2003-06-01  102      10404
# 6   2003-07-01  103      10609
# 7   2003-08-01  104      10816
# 8   2003-09-01  105      11025
# 9   2003-10-01  106      11236
# 10  2003-10-01  107      11449

# %% [markdown]
# # Build the model on entire dataset

# %%
model_full = smf.ols('Passengers~t',data=airline1).fit()
pred_new  = pd.Series(model_full.predict(newdata))
pred_new
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 model_full = smf.ols('Passengers~t',data=airline1).fit()
#       2 pred_new  = pd.Series(model_full.predict(newdata))
#       3 pred_new
#
# AttributeError: module 'statsmodels.api' has no attribute 'ols'

# %%
newdata["forecasted_passengers"]=pd.Series(pred_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 newdata["forecasted_passengers"]=pd.Series(pred_new)
#
# NameError: name 'pred_new' is not defined

# %%
newdata
# Out:
#          Month    t  t_squared
# 0   2003-01-01   97       9409
# 1   2003-02-01   98       9604
# 2   2003-03-01   99       9801
# 3   2003-04-01  100      10000
# 4   2003-05-01  101      10201
# 5   2003-06-01  102      10404
# 6   2003-07-01  103      10609
# 7   2003-08-01  104      10816
# 8   2003-09-01  105      11025
# 9   2003-10-01  106      11236
# 10  2003-10-01  107      11449

# %% [markdown]
# ### OBSERVATION:
#
# ##### Multiplicative Additive Seasonality gives the best prediction of least RMSE of 9.42
